# %%
# import modules
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd

# %% [markdown]
# # Extract data from files

# %%
# read data from file
f = open("data", 'r')
lines = f.readlines()
f.close()
at_aver = []
bst_aver = []
for line in lines:
    l = line.split()
    at_aver.append(int(l[0]))
    bst_aver.append(int(l[1]))
aver_data = np.zeros((len(at_aver),2), dtype=int)
for i in range(len(at_aver)):
    aver_data[i,0] = at_aver[i]
    aver_data[i,1] = bst_aver[i]
df = pd.DataFrame(aver_data)
df.columns = ['<at_i+1 - at_i>', '<bst>']
df.head()
# Out:
#    <at_i+1 - at_i>  <bst>
# 0                0      0
# 1                0      1
# 2                0      2
# 3                0      3
# 4                0      4

# %%
# read SJF_P -> Shortest Job First file (preemptive)
f = open("SJF_P", 'r')
lines = f.readlines()
f.close()
tat = []
wt = []
for line in lines:
    l = line.split()
    tat.append(float(l[1]))
    wt.append(float(l[0]))
tat = np.array(tat)
wt = np.array(wt)
df['<wt> (SJF_P)'] = wt
df['<tat> (SJF_P)'] = tat
df.head()
# Out:
#    <at_i+1 - at_i>  <bst>  <wt> (SJF_P)  <tat> (SJF_P)
# 0                0      0       1800.40        1838.20
# 1                0      1       1798.97        1838.65
# 2                0      2       1608.49        1644.31
# 3                0      3       1929.45        1970.06
# 4                0      4       1688.68        1727.45

# %%
# read SJF_NP -> Shortest Job first non preemptive
f = open("SJF_NP", 'r')
lines = f.readlines()
f.close()
tat = []
wt = []
for line in lines:
    l = line.split()
    tat.append(float(l[1]))
    wt.append(float(l[0]))
tat = np.array(tat)
wt = np.array(wt)
df['<wt> (SJF_NP)'] = wt
df['<tat> (SJF_NP)'] = tat
df.head()
# Out:
#    <at_i+1 - at_i>  <bst>  <wt> (SJF_P)  <tat> (SJF_P)  <wt> (SJF_NP)  \
# 0                0      0       1800.40        1838.20        1621.46
# 1                0      1       1798.97        1838.65        1609.19
# 2                0      2       1608.49        1644.31        1608.49
# 3                0      3       1929.45        1970.06        1929.45
# 4                0      4       1688.68        1727.45        1314.95
#
#    <tat> (SJF_NP)
# 0         1659.26
# 1         1648.87
# 2         1644.31
# 3         1970.06
# 4         1353.72

# %%
# read RR -> Round Robin
f = open("RR_ALG", 'r')
lines = f.readlines()
f.close()
tat = []
wt = []
for line in lines:
    l = line.split()
    tat.append(float(l[1]))
    wt.append(float(l[0]))
tat = np.array(tat)
wt = np.array(wt)
df['<wt> (RR)'] = wt
df['<tat> (RR)'] = tat
df.head()
# Out:
#    <at_i+1 - at_i>  <bst>  <wt> (SJF_P)  <tat> (SJF_P)  <wt> (SJF_NP)  \
# 0                0      0       1800.40        1838.20        1621.46
# 1                0      1       1798.97        1838.65        1609.19
# 2                0      2       1608.49        1644.31        1608.49
# 3                0      3       1929.45        1970.06        1929.45
# 4                0      4       1688.68        1727.45        1314.95
#
#    <tat> (SJF_NP)  <wt> (RR)  <tat> (RR)
# 0         1659.26      97.83     2154.66
# 1         1648.87      98.09     2283.79
# 2         1644.31      96.78     1920.55
# 3         1970.06      96.96     2418.44
# 4         1353.72      98.37     2128.69

# %%
# read PR_ALG -> Priority algorithm
f = open("PR_ALG", 'r')
lines = f.readlines()
f.close()
tat = []
wt = []
for line in lines:
    l = line.split()
    tat.append(float(l[1]))
    wt.append(float(l[0]))
tat = np.array(tat)
wt = np.array(wt)
df['<wt> (PR)'] = wt
df['<tat> (PR)'] = tat
df.head()
# Out:
#    <at_i+1 - at_i>  <bst>  <wt> (SJF_P)  <tat> (SJF_P)  <wt> (SJF_NP)  \
# 0                0      0       1800.40        1838.20        1621.46
# 1                0      1       1798.97        1838.65        1609.19
# 2                0      2       1608.49        1644.31        1608.49
# 3                0      3       1929.45        1970.06        1929.45
# 4                0      4       1688.68        1727.45        1314.95
#
#    <tat> (SJF_NP)  <wt> (RR)  <tat> (RR)  <wt> (PR)  <tat> (PR)
# 0         1659.26      97.83     2154.66    1866.00     1903.80
# 1         1648.87      98.09     2283.79    1769.59     1809.27
# 2         1644.31      96.78     1920.55    1875.47     1911.29
# 3         1970.06      96.96     2418.44    2035.92     2076.53
# 4         1353.72      98.37     2128.69    2014.97     2053.74

# %%
# read FCFS -> First come first serve
f = open("FCFS", 'r')
lines = f.readlines()
f.close()
tat = []
wt = []
for line in lines:
    l = line.split()
    tat.append(float(l[1]))
    wt.append(float(l[0]))
tat = np.array(tat)
wt = np.array(wt)
df['<wt> (FCFS)'] = wt
df['<tat> (FCFS)'] = tat
df.head()
# Out:
#    <at_i+1 - at_i>  <bst>  <wt> (SJF_P)  <tat> (SJF_P)  <wt> (SJF_NP)  \
# 0                0      0       1800.40        1838.20        1621.46
# 1                0      1       1798.97        1838.65        1609.19
# 2                0      2       1608.49        1644.31        1608.49
# 3                0      3       1929.45        1970.06        1929.45
# 4                0      4       1688.68        1727.45        1314.95
#
#    <tat> (SJF_NP)  <wt> (RR)  <tat> (RR)  <wt> (PR)  <tat> (PR)  <wt> (FCFS)  \
# 0         1659.26      97.83     2154.66    1866.00     1903.80      1837.30
# 1         1648.87      98.09     2283.79    1769.59     1809.27      1885.60
# 2         1644.31      96.78     1920.55    1875.47     1911.29      1845.74
# 3         1970.06      96.96     2418.44    2035.92     2076.53      2148.88
# 4         1353.72      98.37     2128.69    2014.97     2053.74      2053.40
#
#    <tat> (FCFS)
# 0       1875.10
# 1       1925.28
# 2       1881.56
# 3       2189.49
# 4       2092.17

# %% [markdown]
# # build data frame with algorithm minimum wt

# %%
df2 = df.copy()
df2 = df2.drop(['<at_i+1 - at_i>'], axis = 1)
df2 = df2.drop(['<bst>'], axis = 1)
df2 = df2.drop(['<tat> (SJF_P)'], axis = 1)
df2 = df2.drop(['<tat> (SJF_NP)'], axis = 1)
df2 = df2.drop(['<tat> (RR)'], axis = 1)
df2 = df2.drop(['<tat> (PR)'], axis = 1)
df2 = df2.drop(['<tat> (FCFS)'], axis = 1)
minValuesdf = df2.idxmin(axis=1)
#
df3 = df.copy()
df3 = df3.drop(['<tat> (SJF_P)'], axis = 1)
df3 = df3.drop(['<tat> (SJF_NP)'], axis = 1)
df3 = df3.drop(['<tat> (RR)'], axis = 1)
df3 = df3.drop(['<tat> (PR)'], axis = 1)
df3 = df3.drop(['<tat> (FCFS)'], axis = 1)
df3 = df3.drop(['<wt> (SJF_P)'], axis = 1)
df3 = df3.drop(['<wt> (SJF_NP)'], axis = 1)
df3 = df3.drop(['<wt> (RR)'], axis = 1)
df3 = df3.drop(['<wt> (PR)'], axis = 1)
df3 = df3.drop(['<wt> (FCFS)'], axis = 1)
df3['ALGO'] = minValuesdf

# %%
df3.head()
# Out:
#    <at_i+1 - at_i>  <bst>       ALGO
# 0                0      0  <wt> (RR)
# 1                0      1  <wt> (RR)
# 2                0      2  <wt> (RR)
# 3                0      3  <wt> (RR)
# 4                0      4  <wt> (RR)

# %% [markdown]
# # Find algorithm minimum turn around time

# %%
df2 = df.copy()
df2 = df2.drop(['<at_i+1 - at_i>'], axis = 1)
df2 = df2.drop(['<bst>'], axis = 1)
df2 = df2.drop(['<wt> (SJF_P)'], axis = 1)
df2 = df2.drop(['<wt> (SJF_NP)'], axis = 1)
df2 = df2.drop(['<wt> (RR)'], axis = 1)
df2 = df2.drop(['<wt> (PR)'], axis = 1)
df2 = df2.drop(['<wt> (FCFS)'], axis = 1)
minValuesdf = df2.idxmin(axis=1)
#
df4 = df.copy()
df4 = df4.drop(['<tat> (SJF_P)'], axis = 1)
df4 = df4.drop(['<tat> (SJF_NP)'], axis = 1)
df4 = df4.drop(['<tat> (RR)'], axis = 1)
df4 = df4.drop(['<tat> (PR)'], axis = 1)
df4 = df4.drop(['<tat> (FCFS)'], axis = 1)
df4 = df4.drop(['<wt> (SJF_P)'], axis = 1)
df4 = df4.drop(['<wt> (SJF_NP)'], axis = 1)
df4 = df4.drop(['<wt> (RR)'], axis = 1)
df4 = df4.drop(['<wt> (PR)'], axis = 1)
df4 = df4.drop(['<wt> (FCFS)'], axis = 1)
df4['ALGO'] = minValuesdf

# %%
df4.head()
# Out:
#    <at_i+1 - at_i>  <bst>            ALGO
# 0                0      0  <tat> (SJF_NP)
# 1                0      1  <tat> (SJF_NP)
# 2                0      2   <tat> (SJF_P)
# 3                0      3   <tat> (SJF_P)
# 4                0      4  <tat> (SJF_NP)

# %% [markdown]
# # Apply KNN to turn around time

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
X = df4.drop(['ALGO'], axis=1)
y = df4['ALGO']
knn = KNeighborsClassifier(n_neighbors=3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=32)
# train the model
knn.fit(X_train, y_train)
s=knn.score(X_test, y_test)
print(s)
# predict response for test
y_pred = knn.predict(X_test)
y_pred
y_test
# Out:
# 0.996
# 5097    <tat> (SJF_NP)
# 2580    <tat> (SJF_NP)
# 260     <tat> (SJF_NP)
# 6781    <tat> (SJF_NP)
# 5468    <tat> (SJF_NP)
#              ...
# 2717    <tat> (SJF_NP)
# 9973    <tat> (SJF_NP)
# 2447    <tat> (SJF_NP)
# 8324    <tat> (SJF_NP)
# 8869    <tat> (SJF_NP)
# Name: ALGO, Length: 3000, dtype: object

# %% [markdown]
# # Apply KNN to waiting time

# %%
X = df3.drop(['ALGO'], axis=1)
y = df3['ALGO']
knn = KNeighborsClassifier(n_neighbors=3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=32)
# train the model
knn.fit(X_train, y_train)
s=knn.score(X_test, y_test)
print(s)
# predict response for test
y_pred = knn.predict(X_test)
y_pred
y_test
# Out:
# 0.9926666666666667
# 5097    <wt> (RR)
# 2580    <wt> (RR)
# 260     <wt> (RR)
# 6781    <wt> (RR)
# 5468    <wt> (RR)
#           ...
# 2717    <wt> (RR)
# 9973    <wt> (RR)
# 2447    <wt> (RR)
# 8324    <wt> (RR)
# 8869    <wt> (RR)
# Name: ALGO, Length: 3000, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
sns.catplot(x="<at_i+1 - at_i>", y="<bst>", hue="ALGO", kind="swarm", data=df3)
# Out:
# /home/jacopo/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 66.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="<at_i+1 - at_i>", y="<bst>", hue="ALGO", kind="swarm", data=df4)
